# %%
import numpy as np 
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# ## Printing specific data types in panda
#
# booleans = []
#
#
# for data in train.dtypes:
#
#
#     if data  == 'int64':
#         booleans.append(True)
#
#
#     else :
#         booleans.append(False)
# '''

# %% [markdown]
# '''trainint_list = pd.Series(booleans)
#
#
# trainint_header  = train.columns[trainint_list]
# '''

# %%
traindata = train.select_dtypes(exclude = 'object')
traindata
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
traindataquant = traindata.drop(columns = ['MSSubClass', 'YearBuilt', 'YearRemodAdd','MoSold','YrSold'])
traindataquant
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  \
# 0        1         65.0     8450            7            5       196.0
# 1        2         80.0     9600            6            8         0.0
# 2        3         68.0    11250            7            5       162.0
# 3        4         60.0     9550            7            5         0.0
# 4        5         84.0    14260            8            5       350.0
# ...    ...          ...      ...          ...          ...         ...
# 1455  1456         62.0     7917            6            5         0.0
# 1456  1457         85.0    13175            6            6       119.0
# 1457  1458         66.0     9042            7            9         0.0
# 1458  1459         68.0     9717            5            6         0.0
# 1459  1460         75.0     9937            5            6         0.0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageCars  \
# ...

# %%
trainint = train[trainint_header]
trainint
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
#data_acquisition = pd.read_table('data_description.txt')
# ?pd.read_table
